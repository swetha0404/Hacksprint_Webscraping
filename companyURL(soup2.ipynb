# %%
import requests as req
from bs4 import BeautifulSoup

# %%
import xlrd
import xlwt
from xlwt import Workbook

# %%
def addDirectors(company,link):
    if link!=None:
    
        link=link.replace("company","company-directors")
        r=req.get(link)
        soup=BeautifulSoup(r.content)
        attr={"class":"table table-striped"}
        names=[]
        wb=Workbook()
        sheet=wb.add_sheet('Directors')
        for i in soup.find_all("table",attr):
            for j in i.find_all("tr"):
                for k in j.find_all("td"):
                    for l in k.find_all("h5"):
                        for m in k.find_all("a"):
                            if m.text.isupper():
                                names.append(m.text)
        print(names)

def companySearch(s):
    if s!="":
        company=s.replace(" ","-")
        company=company.lower()
        
        url="https://www.zaubacorp.com/companysearchresults/"+company
        attr={"class":"container basic-cont"}
        r=req.get(url)
        soup=BeautifulSoup(r.content)


        l=soup.find_all("div",attr)
        child=list(l[0].children)
        text=str(child[2])
        if text[4:len(text)-4].startswith("We are unable to find"):
            print(s.upper())
            print("Company information not available in Zauba")
            return None
            
        else:
            
            l=soup.find_all("h5")            
            id=str(l[0])[4:len(l[0])-6]         
            url="https://www.zaubacorp.com/company/"+company.upper()+"/"+id
            print(s.upper())
            print(url)
                     
            return url

loc="G:\HS302_PS11\cgSummaryReport_1601003730608.xls"
wb=xlrd.open_workbook(loc)
wb1=Workbook()
sheet=wb.sheet_by_index(0)
sheet1=wb1.add_sheet('URL of Companies')
sheet1.write(0,0,"")
sheet1.write(0,1,"URL of Company")
s_no=1

for i in range(3,sheet.nrows-1):
    #companySearch(sheet.cell_value(i,1))
  
    l=companySearch(sheet.cell_value(i,1))
    if l!=None:
        sheet1.write(s_no,0,str(s_no))
        sheet1.write(s_no,1,l)
        s_no+=1
    addDirectors(sheet.cell_value(i,1),l)
        
wb1.save("G:/HS302_PS11/URL of Companies.xls")
# Out:
# BIBBY FINANCIAL SERVICES INDIA PRIVATE LIMITED
# [' ANOOP KUMAR PRABHAKAR', ' IAN DOWNING']
# CANBANK FACTORS LIMITED
# [' LALITHA RAMESWARAN', ' BISWAJIT RAY', ' ARUMUGAM MANIMEKHALAI', ' CHANDRAMOHAN DEVULAPALLE REDDY']
# GENERAL INSURANCE CORPORATION OF INDIA
# [' GOVIND BALLABH PANDE', ' DAKSHITA DAS', ' ATANU KUMAR DAS', ' AMARENDRA PRATAP SINGH', ' RAMASAMY VENKATARAMAN']
# IFCI FACTORS LIMITED
# [' BIRANCHI NARAYAN NAYAK', ' SURESH KUMAR JAIN', ' BIKASH KANTI ROY', ' EMANDI SANKARA RAO', ' ARVIND KUMAR JAIN', ' MADHUSHREE NANDA AGARWAL']
# IFCI LIMITED
# [' ARVIND SAHAY', ' ANAND MADHUKAR', ' MADAN MOHANLAL VERMA']
# INDUSTRIAL INVESTMENT BANK OF INDIA LIMITED
# [' VIRENDRA KUMAR DHINGRA', ' SHASHANK SAKSENA', ' SUNANDA LAHIRI']
# LIC HOUSING
# [' JAGDISH CAPOOR', ' SIDDHARTHA MOHANTY', ' AMEET NAVINCHANDRA PATEL', ' KASHI PRASAD KHANDELWAL', ' DHARMENDRA BHANDARI', ' VIPAN KUMAR KUKREJA', ' VIPIN ANAND', ' MANGALAM RAMASUBRAMANIAN KUMAR', ' POTTIMUTYALA KOTESWARA RAO', ' SAVITA PARAM BIR SINGH']
# POWER FINANCE CORPORATION LIMITED
# [' RAJEEV SHARMA', ' RAM CHANDRA MISHRA', ' GOURI CHAUDHURY', ' RAVINDER SINGH DHILLON']
# SBI GLOBAL FACTORS LIMITED
# [' BHARATI RAO', ' VINAY SUDHAKARRAO HEDAOO', ' ARAVINDKUMAR NARASIMHA MARUR', ' VIJAY KUMAR GUPTA', ' NARAYANAN RAJA']
# SICOM LIMITED
# [' SATISH MADHUKAR GAVAI', ' KAVITA GUPTA', ' DEBA PRASAD ROY', ' RAHUL GUPTA', ' SUNEET SHRINIWAS MAHESHWARI']
# SIDBI
# [' BALA C DESHPANDE', ' ARVIND KUMAR JAIN', ' ARCHANA NIRANJAN HINGORANI', ' SATYA PRAKASH SINGH', ' MUSTAFA MOHAMMAD', ' MANOJ MITTAL', ' MANOJ MITTAL']
# TIIC LTD.
# [' GYANCHAND PIPARA', ' ALKA GYAN PIPARA']
# UTI MUTUAL FUND
# []
# BANK OF AMERICA
# []
# BANK OF CEYLON
# []
# BANK OF CHINA LIMITED
# []
# BNP PARIBAS
# []
# CITIBANK N.A.
# [' SURAJ KANT', ' RAJNI KANT', ' CHANDER KANT', ' KANTA DEVI']
# CREDIT AGRICOLE CORPORATE & INVESTMENT BANK
# []
# CREDIT SUISSE AG
# []
# DEUTSCHE BANK
# []
# EMIRATES NBD BANK (P.J.S.C)
# []
# INDUSTRIAL BANK OF KOREA
# []
# JSC VTB BANK
# []
# SOCIETE GENERALE
# [' MONA RIKHIL SHAH', ' NICOLAS STUM', ' SUJIT SURESHCHANDRA KADAKIA']
# STANDARD CHARTERED BANK
# []
# SUMITOMO MITSUI BANKING CORPORATION
# []
# EDELWEISS HOUSING FINANCE LIMITED
# [' DEEPAK MITTAL', ' SIDDHARTH KRISHNASWAMY', ' PUDUGRAMAM NARAYANASWAMY VENKATACHALAM', ' SUNIL NAWAL PHATARPHEKAR']
# HOUSING DEVELOPMENT FINANCE CORPORATION LTD
# []
# INDIABULLS HOUSING FINANCE LIMITED
# [' AJIT KUMAR MITTAL', ' SIDDHARTH ACHUTHAN', ' SHAMSHER SINGH AHLAWAT', ' GAGAN BANGA', ' SAMEER GEHLAUT', ' ASHWINI OMPRAKASH KUMAR', ' SATISHCHAND MATHUR', ' PREM PRAKASH MIRDHA', ' SACHIN CHAUDHARY', ' KAMALESH SHAILESH CHANDRA CHAKRABARTY', ' GYAN SUDHA MISRA', ' SUBHASH SHEORATAN MUNDRA']
